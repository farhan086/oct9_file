# %%
import pandas as pd

# %%
# Create the dataset
data = {
    'House_size' : [850, 900, 1200, 1350, 1500, 1600, 1850, 2100, 2300, 2500],
    'Bedrooms' :  [2, 2, 3, 3, 3, 3, 4, 4, 4, 5],
    'Price' : [110, 115, 140, 155, 170, 180, 200, 240, 275, 300, ]

}

# %%
df=pd.DataFrame(data)

# %%
df.head()
# Out:
#    House_size  Bedrooms  Price
# 0         850         2    110
# 1         900         2    115
# 2        1200         3    140
# 3        1350         3    155
# 4        1500         3    170

# %%
# if i have any missing values
df.isnull().sum()
# Out:
# House_size    0
# Bedrooms      0
# Price         0
# dtype: int64

# %%
# let's check or detect the outliers
import seaborn as sns
sns.boxplot (df["House_size"])
# Out:
# <Axes: ylabel='House_size'>

# %%
sns.boxplot (df["Bedrooms"])
# Out:
# <Axes: ylabel='Bedrooms'>

# %%
sns.boxplot(df["Price"])
# Out:
# <Axes: ylabel='Price'>

# %%
# do i need to encode? no need, we don't categorical  variable/columns
# we need to split the data into 80(training) and 20(testing)
from sklearn.model_selection import train_test_split

# %%
# Define features and target variable
X = df[['House_size', 'Bedrooms']]  # Feature
y = df['Price']  # Target variable

# %%
X.head()   # These are my independent variables
# Out:
#    House_size  Bedrooms
# 0         850         2
# 1         900         2
# 2        1200         3
# 3        1350         3
# 4        1500         3

# %%
y # dependent variable
# Out:
# 0    110
# 1    115
# 2    140
# 3    155
# 4    170
# 5    180
# 6    200
# 7    240
# 8    275
# 9    300
# Name: Price, dtype: int64

# %%
X_train, X_test, y_train, y_test =train_test_split (X,y,test_size=0.2, random_state=0)

# %%
X_train
# Out:
#    House_size  Bedrooms
# 4        1500         3
# 9        2500         5
# 1         900         2
# 6        1850         4
# 7        2100         4
# 3        1350         3
# 0         850         2
# 5        1600         3

# %%
X_test
# Out:
#    House_size  Bedrooms
# 2        1200         3
# 8        2300         4

# %%
y_train
# Out:
# 4    170
# 9    300
# 1    115
# 6    200
# 7    240
# 3    155
# 0    110
# 5    180
# Name: Price, dtype: int64

# %%
y_test  # dependent test data
# Out:
# 2    140
# 8    275
# Name: Price, dtype: int64

# %%
df.shape
# Out:
# (10, 3)

# %%
# Train the model
from sklearn.linear_model import LinearRegression
linear_reg = LinearRegression()

# %%
# how do we train the model(training)
linear_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#    House_size  Bedrooms
# 2        1200         3
# 8        2300         4

# %%
# y_pred
y_test
# Out:
# 2    140
# 8    275
# Name: Price, dtype: int64

# %%
y_pred =linear_reg.predict(X_test)

# %%
y_pred
# Out:
# array([141.42271663, 263.50409836])

# %%
# How do we evaluate the performance of the model
# cost function ? MSE or RMSE
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_test, y_pred)

# %%
print(mse)
# Out:
# 67.08993855201301

# %%
import numpy as np
rmse=np.sqrt(mse)

# %%
rmse
# Out:
# np.float64(8.190844800874512)

# %%
import joblib
joblib.dump(linear_reg, 'mul_linear.pkl')
# Out:
# ['mul_linear.pkl']
